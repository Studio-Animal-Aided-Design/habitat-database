# %%
import sys
#!{sys.executable} -m pip install pandas
#!{sys.executable} -m pip install openpyxl
#!{sys.executable} -m pip install python-slugify

# %%
import pandas as pd

# Load the Excel file
file_path = '../20241106_NEB AAD Habitatelemente Zielarten.xlsx'
xls = pd.ExcelFile(file_path)

# Check the sheet names to locate "Arbeitsblatt (Habitatelemente_Zielarten)"
xls.sheet_names
# Out:
# ['Habitatelemente_Zielarten', 'Habitatelemente']

# %%
# Load the sheet "Habitatelemente_Zielarten"
df = pd.read_excel(xls, sheet_name='Habitatelemente_Zielarten')

# Check the first few rows to understand its structure
df.head()
# Out:
#        Habitatelement   Funktion Funktionselement             Name_dt  \
# 0  (junge) Nadelbäume  Brutplatz    dichte Zweige              Gimpel
# 1       (Wild-)Hecken    Nahrung         Insekten         Mauersegler
# 2       (Wild-)Hecken    Nahrung         Insekten     Zwergfledermaus
# 3       (Wild-)Hecken    Nahrung         Insekten  Zweifarbfledermaus
# 4       (Wild-)Hecken  Schutzort   Blätter/Zweige       Grauschnäpper
#
#   Entwicklungsstadium
# 0               adult
# 1      adult, juvenil
# 2               adult
# 3               adult
# 4      adult, juvenil

# %%
# load species CSV
# !! make sure to run species importer script first

file_path = '../../species-portraits/classification/import/out/species.csv'
species_df = pd.read_csv(file_path)

species_df
# Out:
#     id            scientific_name  alternative_scientific_name  \
# 0  NaN                  Apus apus                          NaN
# 1  NaN          Pyrrhula pyrrhula                          NaN
# 2  NaN          Muscicapa striata                          NaN
# 3  NaN    Phoenicurus phoenicurus                          NaN
# 4  NaN          Passer domesticus                          NaN
# 5  NaN              Picus viridis                          NaN
# 6  NaN        Andrena barbilabris                          NaN
# 7  NaN        Anthophora plumipes                          NaN
# 8  NaN       Anthidium oblongatum                          NaN
# 9  NaN              Plebejus idas                          NaN
# 10 NaN            Papilio machaon                          NaN
# 11 NaN  Pipistrellus pipistrellus                          NaN
# 12 NaN        Vespertilio murinus                          NaN
# 13 NaN             Lacerta agilis                          NaN
#
#             common_name alternative_common_name class_common class_scientific  \
# 0           Mauersegler                     NaN        Vögel             Aves
# 1                Gimpel                Dompfaff        Vögel             Aves
# 2         Grauschnäpper                     NaN        Vögel             Aves
# 3      Gartenrotschwanz                     NaN        Vögel             Aves
# 4          Haussperling               Hausspatz        Vögel             Aves
# 5            Grünspecht               Erdspecht        Vögel             Aves
# 6     Bärtige Sandbiene   Schwimmende Sandbiene     Insekten          Insecta
# 7   Frühlings-Pelzbiene       Gemeine Pelzbiene     Insekten          Insecta
# 8     Spalten-Wollbiene   Felsspalten-Wollbiene     Insekten          Insecta
# 9         Idas-Bläuling        Ginster-Bläuling     Insekten          Insecta
# 10     Schwalbenschwanz                     NaN     Insekten          Insecta
# 11      Zwergfledermaus                     NaN   Säugetiere         Mammalia
# 12   Zweifarbfledermaus                     NaN   Säugetiere         Mammalia
# 13         Zauneidechse                     NaN    Reptilien         Reptilia
#
#            order_common order_scientific       family_common  \
# 0           Seglervögel      Apidiformes              Segler
# 1        Sperlingsvögel    Passeriformes              Finken
# 2        Sperlingsvögel    Passeriformes    Fliegenschnäpper
# 3        Sperlingsvögel    Passeriformes    Fliegenschnäpper
# 4        Sperlingsvögel    Passeriformes           Sperlinge
# 5           Spechtvögel       Piciformes             Spechte
# 6           Hautflügler      Hymenoptera                 NaN
# 7           Hautflügler      Hymenoptera        Echte Bienen
# 8           Hautflügler      Hymenoptera  Bauchsammlerbienen
# 9        Schmetterlinge      Lepidoptera           Bläulinge
# 10       Schmetterlinge      Lepidoptera        Ritterfalter
# 11          Fledertiere       Chiroptera          Glattnasen
# 12          Fledertiere       Chiroptera          Glattnasen
# 13  Schuppenkriechtiere         Squamata     Echte Eidechsen
#
#    family_scientific          genus_common genus_scientific
# 0           Apodidae                   NaN             Apus
# 1       Fringillidae    Eigentliche Gimpel         Pyrrhula
# 2       Muscicapidae                   NaN        Muscicapa
# 3       Muscicapidae           Rotschwänze      Phoenicurus
# 4         Passeridae                   NaN           Passer
# 5            Picidae                   NaN            Picus
# 6         Andrenidae            Sandbienen          Andrena
# 7             Apidae                   NaN       Anthophora
# 8       Megachilidae  Harz- und Wollbienen        Anthidium
# 9         Lycaenidae                   NaN         Plebejus
# 10      Papilionidae                   NaN          Papilio
# 11  Vespertilionidae   Zweifarbfledermäuse      Vespertilio
# 12  Vespertilionidae   Zweifarbfledermäuse      Vespertilio
# 13        Lacertidae     Halsbandeidechsen          Lacerta

# %%
from slugify import slugify

# Clean the column names for snake_case and English translation
df.columns = [
    'habitat_element', 'purpose', 'purpose_element',
    'species_name', 'lifecycle_stage'
]

# slugify habitat element name to match the generated 
df['habitat_element'] = df['habitat_element'].apply(lambda x: slugify(x, separator="_", replacements=[('ä', 'ae'), ('ö', 'oe'), ('ü', 'ue'), ('ß', 'ss')]))

# get species scientific name from species_name
df = df.merge(species_df[['common_name', 'scientific_name']], left_on='species_name', right_on='common_name', how='left')

print(df.head())
# Out:
#      habitat_element    purpose purpose_element        species_name  \
# 0  junge_nadelbaeume  Brutplatz   dichte Zweige              Gimpel
# 1        wild_hecken    Nahrung        Insekten         Mauersegler
# 2        wild_hecken    Nahrung        Insekten     Zwergfledermaus
# 3        wild_hecken    Nahrung        Insekten  Zweifarbfledermaus
# 4        wild_hecken  Schutzort  Blätter/Zweige       Grauschnäpper
#
#   lifecycle_stage         common_name            scientific_name
# 0           adult              Gimpel          Pyrrhula pyrrhula
# 1  adult, juvenil         Mauersegler                  Apus apus
# 2           adult     Zwergfledermaus  Pipistrellus pipistrellus
# 3           adult  Zweifarbfledermaus        Vespertilio murinus
# 4  adult, juvenil       Grauschnäpper          Muscicapa striata

# %%
# Replace 'species' column with 'scientific_name'
df['species'] = df['scientific_name']

# Drop the temporary 'common_name' column used for the merge
df = df.drop(columns=['common_name', 'species_name', 'scientific_name'])

# Reorder columns
df = df[['habitat_element', 'species', 'lifecycle_stage', 'purpose', 'purpose_element']]

# Hinzufügen einer 'id'-Spalte mit fortlaufenden Ganzzahlen
df.insert(0, 'id', range(1, len(df) + 1))

print(df.head())
# Out:
#    id    habitat_element                    species lifecycle_stage  \
# 0   1  junge_nadelbaeume          Pyrrhula pyrrhula           adult
# 1   2        wild_hecken                  Apus apus  adult, juvenil
# 2   3        wild_hecken  Pipistrellus pipistrellus           adult
# 3   4        wild_hecken        Vespertilio murinus           adult
# 4   5        wild_hecken          Muscicapa striata  adult, juvenil
#
#      purpose purpose_element
# 0  Brutplatz   dichte Zweige
# 1    Nahrung        Insekten
# 2    Nahrung        Insekten
# 3    Nahrung        Insekten
# 4  Schutzort  Blätter/Zweige

# %%
# remove relation records with no matching habitat element
# !! habitat_elements.csvmust be exported first!

file_path = './out/habitat_elements.csv'
habitat_elements_df = pd.read_csv(file_path)

# Check if every 'habitat_element' in habitat_element_species_relation exists in 'id' from habitat_elements
df = df[
    df['habitat_element'].isin(habitat_elements_df['id'])
]

# %%
# Convert to CSV format
csv_file_path = './out/habitat_element_species_relation.csv'
df.to_csv(csv_file_path, index=False)

csv_file_path
# Out:
# './out/habitat_element_species_relation.csv'
